# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/4248710/attachment/5f6b595e63350aa5b55f0ea72561b871.csv',sep=';')

# %% [markdown]
# # Задание 1
#
# ## Вывести на экран первые 5 строк

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %% [markdown]
# ## Посмотреть на описание признаков и на их содержание

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# # Задание 2
# ## Проведите первичный анализ данных
# ### 1. Изучите типы данных

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %% [markdown]
# ### 2. Найдите количество пропущенных ячеек в данных

# %%
df.count()
# Out:
# Company             1303
# Product             1303
# TypeName            1303
# Inches              1303
# ScreenResolution    1303
# Cpu                 1303
# Ram                 1303
# Memory              1303
# Gpu                 1303
# OpSys               1303
# Weight              1303
# Price_euros         1303
# dtype: int64

# %% [markdown]
# # Задание 3
# ## 3.1 Ноутбуков от какой компании больше всего в наборе данных?

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %%
df['Company'].mode()
# Out:
# 0      Dell
# 1    Lenovo
# dtype: object

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %% [markdown]
# ## 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
df['Price_euros'].max()
# Out:
# 6099.0

# %%
df['Price_euros'].min()
# Out:
# 174.0

# %% [markdown]
# ## 3.3 Какой самый дорогой ноутбук в данных?

# %%
df[df['Price_euros'] == df['Price_euros'].max() ]
# Out:
#     Company    Product TypeName  Inches                     ScreenResolution  \
# 196   Razer  Blade Pro   Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu   Ram   Memory                      Gpu  \
# 196  Intel Core i7 7820HK 2.9GHz  32GB  1TB SSD  Nvidia GeForce GTX 1080
#
#           OpSys  Weight  Price_euros
# 196  Windows 10  3.49kg       6099.0

# %% [markdown]
# # Задание 4
# ## 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?

# %%
df[df['Inches'] == df['Inches'].min()][['Company','TypeName','Inches','Price_euros']]
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# ## 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[(df['Company'] == 'HP') & (df['Price_euros'] == df['Price_euros'].max() )]
# Out:
# Empty DataFrame
# Columns: [Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros]
# Index: []

# %%
df_HP = df[df['Company'] == 'HP' ]

# %%
df_HP['Price_euros'].max()
# Out:
# 4389.0

# %%
df_HP[df_HP['Price_euros']==df_HP['Price_euros'].max()]
# Out:
#     Company   Product     TypeName  Inches             ScreenResolution  \
# 749      HP  Zbook 17  Workstation    17.3  IPS Panel Full HD 1920x1080
#
#                                Cpu   Ram     Memory                   Gpu  \
# 749  Intel Xeon E3-1535M v5 2.9GHz  16GB  256GB SSD  Nvidia Quadro M2000M
#
#          OpSys Weight  Price_euros
# 749  Windows 7    3kg       4389.0

# %% [markdown]
# ## 4.3 Как много ноутбуков Ultrabook с 8GB RAM?

# %%
ultra_8GB = df[(df['TypeName'] == 'Ultrabook') & (df['Ram'] == '8GB')].shape[0]

# %%
ultra = df[df['TypeName'] == 'Ultrabook'].shape[0]

# %%
share = ultra_8GB/ultra
print(share)
# Out:
# 0.7142857142857143

# %% [markdown]
# # Задание 5
# ## 5.1 Выберите ноутбук клиенту
# ### Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?

# %%
client_1 = df[((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) & (df['OpSys'] == 'Windows 10') & (df['Price_euros'] <= 500)]

# %%
client_1.shape[0]
# Out:
# 13

# %% [markdown]
# ## 5.2 Выберите ноутбук клиенту
# ### Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
client_2 = df[(df['Company'] == 'MSI') & (df['Gpu'] == 'Nvidia GeForce GTX 1050 Ti') & ~ (df['Inches'] == 15.6)]

# %%
client_2
# Out:
#      Company        Product TypeName  Inches   ScreenResolution  \
# 330      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393      MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 724      MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917      MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1156     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# 393   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1349.00
# ...

# %%
[client_2['Price_euros'].min(), client_2['Price_euros'].max()]
# Out:
# [1199.0, 1599.0]

# %% [markdown]
# ## 5.3 Что дешевле?
# ### В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
result_1 = df[df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean()
result_1
# Out:
# 1760.4084246575337

# %%
result_2 = df[df['Cpu'] == 'Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()
result_2
# Out:
# 1915.710769230769

# %% [markdown]
# # Задание 6
# ## Найдите самый легкий ноутбук
# ### Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
print(type(df.iloc[0,10]))
# Out:
# <class 'str'>

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69
# ...

# %%
df['Weight'].min()
# Out:
# '0.69'

# %%
df[df['Weight'] == df['Weight'].min()]
# Out:
#      Company    Product            TypeName  Inches  \
# 50    Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1082  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1114  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1126  Lenovo  Yoga Book  2 in 1 Convertible    10.1
#
#                      ScreenResolution                          Cpu  Ram  \
# 50    IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1082  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1114  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1126  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                   Memory                    Gpu       OpSys Weight  \
# 50    64GB Flash Storage  Intel HD Graphics 400     Android   0.69
# 1082  64GB Flash Storage  Intel HD Graphics 400  Windows 10   0.69
# 1114  64GB Flash Storage  Intel HD Graphics 400     Android   0.69
# 1126  64GB Flash Storage  Intel HD Graphics 400  Windows 10   0.69
#
# ...

# %% [markdown]
# # Домашнее задание 1
# ### Считать данные с помощью pandas
# ### Вывести на экран первые 5 строк
# ### Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
import numpy as np

# %%
re = pd.read_csv('/Users/macbookpro/Downloads/kc_house_data.csv', sep=',')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # Домашнее задание 2
# ### 2.1 Изучите типы данных
# ### 2.2 Найдите количество пропущенных ячеек в данных
# ### 2.3 Посчитайте основные статистики по всем признакам и поизучайте их

# %%
print(type(re))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
re.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
re.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
re.describe(['price'], ['bedrooms'], ['sqft_living'],  ['sqft_lot'], ['sqft_basement'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/yj/9y6wn5pj3w7g3fxymw4tb5jm0000gn/T/ipykernel_3085/1260404596.py in <module>
# ----> 1 re.describe(['price'], ['bedrooms'], ['sqft_living'],  ['sqft_lot'], ['sqft_basement'])
#
# TypeError: describe() takes from 1 to 5 positional arguments but 6 were given

# %% [markdown]
# ##### 2.1: тип данных: pandas.core.frame.DataFrame
# ##### 2.2: пропущенных ячеек нет (по всем признакам стоит non-null)
# ##### 2.3:  выведена статистика по всем  признакам

# %% [markdown]
# # Домашнее задание 3
# ### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
[re['price'].min(),re['price'].max()]
# Out:
# [75000.0, 7700000.0]

# %% [markdown]
# ##### изменяется в диапазоне от 75 000 до 7 700 000

# %% [markdown]
# ### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
re.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
living_sqr = re['sqft_living'].values.sum()
total_sqr = re['sqft_lot'].values.sum()

# %%
share = living_sqr/total_sqr
share
# Out:
# 0.1376781757959227

# %% [markdown]
# ##### доля жилой недвижимости в общей порядока 14%

# %% [markdown]
# ### 3.3 Как много домов с разными этажами в данных?

# %%
result =  re['floors'] > 1.0

# %%
result.sum()
# Out:
# 10933

# %%
re['floors'].shape[0]
# Out:
# 21613

# %% [markdown]
# ##### из 21 613 домов 10 933 - дома с разными этажами

# %% [markdown]
# ### 3.4 Насколько хорошее состояния у домов в данных?

# %%
re.head(20)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
re['condition'].shape[0]
# Out:
# 21613

# %%
poor_state = re[re['condition'] < 3]
poor_state.shape[0]
# Out:
# 202

# %%
mid_state = re[re['condition'] == 3]
mid_state.shape[0]
# Out:
# 14031

# %%
perfect_state = re[re['condition'] > 3]
perfect_state.shape[0]
# Out:
# 7380

# %% [markdown]
# ##### 202 дома - в плохом состоянии, 14 031 дом - в среднем состоянии, 7 380 в хорошем состоянии (выше среднего)

# %% [markdown]
# ### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
[re['yr_built'].min(), re['yr_built'].max()]
# Out:
# [1900, 2015]

# %% [markdown]
# ##### Первый дом построили в 1900 году, последний - в 2015

# %% [markdown]
# # Домашнее задание 4
# ### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
re.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
two_bedroom = re[re['bedrooms'] == 2]
two_bedroom['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# ##### средняя стоимость - 401 372

# %% [markdown]
# ### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
expensive = re[re['price'] > 600000]
expensive['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# ### средняя площадь 20 442

# %% [markdown]
# ### 4.3 Как много домов коснулся ремонт?

# %%
renovated = re[re['yr_renovated'] > 0]
renovated.shape[0]
# Out:
# 914

# %% [markdown]
# ##### 914 домов были отремонтированы

# %% [markdown]
# ### 4.4 Насколько в среднем стоимость домов с оценкой grade выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
grade_4_state = re[re['grade'] > 4]
cheap = grade_4_state['price'].mean()

# %%
grade_10_state = re[re['grade'] > 10]
expensive = grade_10_state['price'].mean()

# %%
diff = expensive - cheap
diff
# Out:
# 1138044.3409775172

# %% [markdown]
# ##### качественные дома в среднем дороже на 1 138 044 по сравнению с некачественными домами

# %% [markdown]
# # Домашнее задание 5
# ### 5.1 Выберите дом клиенту
# #### Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
re.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
client_1 = re[(re['waterfront']>0) & (re['bedrooms'] >2) & (re['sqft_basement']>0)]

# %%
client_1.shape[0]
# Out:
# 84

# %% [markdown]
# ##### у клиента есть 84 варианта

# %% [markdown]
# ### 5.2 Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
client_2 = re[((re['view'] == 4) | (re['waterfront'] > 0)) & (re['condition'] == 5) & (re['yr_built'] > 1979)]

# %%
client_2
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 11257  3761100045  20140618T000000  3000000.0         4       4.25
# 14682  7278100515  20140821T000000  1295000.0         2       2.50
# 17312  3585901025  20140613T000000  1735000.0         3       2.50
# 18991  7856400300  20140702T000000  1411600.0         2       2.50
# 18992  7856400300  20150322T000000  1505000.0         2       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 11257         4850     12445     2.0           1     4  ...     10
# 14682         2910     19449     2.0           1     4  ...      9
# 17312         4310     32093     1.5           0     4  ...     10
# 18991         3180      9400     2.0           0     4  ...     10
# 18992         3180      9400     2.0           0     4  ...     10
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 11257        3850           1000      1989             0    98034  47.7011
# ...

# %%
client_2['price'].min(), client_2['price'].max()
# Out:
# (1295000.0, 3000000.0)

# %% [markdown]
# ##### диапазон цен от 1 295 000 до 3 000 000

# %% [markdown]
# ### 5.3 Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
client_3 = re[(re['sqft_basement'] == 0) & (re['floors'] == 2) & (re['price'] < 150000)]

# %%
client_3
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# 18939          980      2490     2.0           0     0  ...      6
# 18988         1200      2002     2.0           0     0  ...      8
#
# ...

# %%
client_3['condition'].mean()
# Out:
# 2.8333333333333335

# %% [markdown]
# ##### средняя оцена состояния - 2.83
